# %% [markdown]
# # Conversion Rate  : Outliers Managed 🏆🏆

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, confusion_matrix

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
#setting Jedha color palette as default
pio.templates["jedha"] = go.layout.Template(
  layout_colorway=["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]
)
pio.templates.default = "jedha"
#pio.renderers.default = "svg" # to be replaced by "iframe" if working on JULIE
from IPython.display import display

# %%
df = pd.read_csv('conversion_data_train.csv')

# %%
#suppression des pages au delà de 16 pages vues
# Suppression des lignes où le nombre total de pages visitées est supérieur à 16 ou inférieur à 2
rowsPV_to_drop = df[(df['total_pages_visited'] > 16) | (df['total_pages_visited'] < 2)].index.tolist()
df = df.drop(rowsPV_to_drop, axis=0)
df.shape
# Out:
# (245019, 6)

# %%
#suppression des âges au delà de 100
rowsAge_to_drop = df[(df['age'] > 90)].index.tolist()
df = df.drop(rowsAge_to_drop, axis=0)
df.shape
# Out:
# (245017, 6)

# %%
df
# Out:
#         country  age  new_user  source  total_pages_visited  converted
# 1            UK   21         1     Ads                    3          0
# 2       Germany   20         0     Seo                   14          1
# 3            US   23         1     Seo                    3          0
# 4            US   28         1  Direct                    3          0
# 5            US   29         0     Seo                    7          0
# ...         ...  ...       ...     ...                  ...        ...
# 284574       UK   23         0     Ads                   14          1
# 284576       US   31         1     Seo                    2          0
# 284577       US   41         1     Seo                    5          0
# 284578       US   31         1  Direct                    4          0
# 284579       US   26         0     Ads                    3          0
#
# [185086 rows x 6 columns]

# %%
# Définition de la cible et des features

target_variable = "converted"
X = df.drop(target_variable, axis=1)
Y = df[target_variable]

# Détection des colonnes numériques et catégorielles
numeric_features = [col for col in X.columns if X[col].dtype in ['int64', 'float64']]
categorical_features = [col for col in X.columns if col not in numeric_features]

# Split train/test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Prétraitement des données
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(drop="first")
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# Transformation des données
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# Encodage des labels
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
Y_test = encoder.transform(Y_test)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# Construire et entraîner le modèle de régression logistique
logistic_model = LogisticRegression()
logistic_model.fit(X_train, Y_train)

# Prédictions
Y_train_pred = logistic_model.predict(X_train)
Y_test_pred = logistic_model.predict(X_test)

# Matrice de confusion pour le train set
cm_train = confusion_matrix(Y_train, Y_train_pred)
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train)
disp_train.plot(cmap='Blues')
plt.title("Matrice de confusion Train Set")
plt.show()

# Métriques pour le train set
print("Métriques pour le train set :")
print(classification_report(Y_train, Y_train_pred))

# Matrice de confusion pour le test set
cm_test = confusion_matrix(Y_test, Y_test_pred)
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test)
disp_test.plot(cmap='Blues')
plt.title("Matrice de confusion Test Set")
plt.show()

# Métriques pour le test set
print("Métriques pour le test set :")
print(classification_report(Y_test, Y_test_pred, digits=4))

# Matrice de confusion globale (train + test)
Y_global = np.concatenate((Y_train, Y_test))
Y_global_pred = np.concatenate((Y_train_pred, Y_test_pred))
cm_global = confusion_matrix(Y_global, Y_global_pred)
disp_global = ConfusionMatrixDisplay(confusion_matrix=cm_global)
disp_global.plot(cmap='Blues')
plt.title("Matrice de confusion Globale")
plt.show()

# Métriques globales
print("Métriques globales :")
print(classification_report(Y_global, Y_global_pred))
# Out:
# Métriques pour le train set :
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    190942
#            1       0.78      0.55      0.65      5071
#
#     accuracy                           0.98    196013
#    macro avg       0.88      0.77      0.82    196013
# weighted avg       0.98      0.98      0.98    196013
# Métriques pour le test set :
#               precision    recall  f1-score   support
#
#            0     0.9881    0.9957    0.9919     47728
#            1     0.7733    0.5533    0.6450      1276
#
#     accuracy                         0.9841     49004
#    macro avg     0.8807    0.7745    0.8185     49004
# weighted avg     0.9826    0.9841    0.9829     49004
# Métriques globales :
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    238670
#            1       0.78      0.55      0.65      6347
#
#     accuracy                           0.98    245017
#    macro avg       0.88      0.77      0.82    245017
# weighted avg       0.98      0.98      0.98    245017

# %%
print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# f1-score on train set :  0.7650520597555455
# f1-score on test set :  0.7572289156626506

# %%
# Construire et entraîner le modèle de Random Forest
from sklearn.ensemble import RandomForestClassifier

random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest_model.fit(X_train, Y_train)

# Prédictions
Y_train_pred = random_forest_model.predict(X_train)
Y_test_pred = random_forest_model.predict(X_test)

# Matrice de confusion pour le train set
cm_train = confusion_matrix(Y_train, Y_train_pred)
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train)
disp_train.plot(cmap='Blues')
plt.title("Matrice de confusion Train Set")
plt.show()

# Métriques pour le train set
print("Métriques pour le train set :")
print(classification_report(Y_train, Y_train_pred, digits=4))

# Matrice de confusion pour le test set
cm_test = confusion_matrix(Y_test, Y_test_pred)
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test)
disp_test.plot(cmap='Blues')
plt.title("Matrice de confusion Test Set")
plt.show()

# Métriques pour le test set
print("Métriques pour le test set :")
print(classification_report(Y_test, Y_test_pred))

# Matrice de confusion globale (train + test)
Y_global = np.concatenate((Y_train, Y_test))
Y_global_pred = np.concatenate((Y_train_pred, Y_test_pred))
cm_global = confusion_matrix(Y_global, Y_global_pred)
disp_global = ConfusionMatrixDisplay(confusion_matrix=cm_global)
disp_global.plot(cmap='Blues')
plt.title("Matrice de confusion Globale")
plt.show()

# Métriques globales
print("Métriques globales :")
print(classification_report(Y_global, Y_global_pred))
# Out:
# Métriques pour le train set :
#               precision    recall  f1-score   support
#
#            0     0.9898    0.9968    0.9933    190942
#            1     0.8338    0.6133    0.7067      5071
#
#     accuracy                         0.9868    196013
#    macro avg     0.9118    0.8050    0.8500    196013
# weighted avg     0.9858    0.9868    0.9859    196013
# Métriques pour le test set :
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     47728
#            1       0.71      0.54      0.61      1276
#
#     accuracy                           0.98     49004
#    macro avg       0.85      0.76      0.80     49004
# weighted avg       0.98      0.98      0.98     49004
# Métriques globales :
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    238670
#            1       0.81      0.60      0.69      6347
#
#     accuracy                           0.99    245017
#    macro avg       0.90      0.80      0.84    245017
# weighted avg       0.98      0.99      0.98    245017

# %%
print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# f1-score on train set :  0.8052898983861327
# f1-score on test set :  0.7378756322523059

# %%
# Construire et entraîner le modèle XGBoost
import xgboost as xgb

xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    max_depth=5,
    learning_rate=0.1,
    n_estimators=100,
    random_state=0
)
xgb_model.fit(X_train, Y_train)

# Prédictions
Y_train_pred = xgb_model.predict(X_train)
Y_test_pred = xgb_model.predict(X_test)

# Matrice de confusion pour le train set
cm_train = confusion_matrix(Y_train, Y_train_pred)
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train)
disp_train.plot(cmap='Blues')
plt.title("Matrice de confusion Train Set")
plt.show()

# Métriques pour le train set
print("Métriques pour le train set :")
print(classification_report(Y_train, Y_train_pred))

# Matrice de confusion pour le test set
cm_test = confusion_matrix(Y_test, Y_test_pred)
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test)
disp_test.plot(cmap='Blues')
plt.title("Matrice de confusion Test Set")
plt.show()

# Métriques pour le test set
print("Métriques pour le test set :")
print(classification_report(Y_test, Y_test_pred, digits=4))

# Matrice de confusion globale (train + test)
Y_global = np.concatenate((Y_train, Y_test))
Y_global_pred = np.concatenate((Y_train_pred, Y_test_pred))
cm_global = confusion_matrix(Y_global, Y_global_pred)
disp_global = ConfusionMatrixDisplay(confusion_matrix=cm_global)
disp_global.plot(cmap='Blues')
plt.title("Matrice de confusion Globale")
plt.show()

# Métriques globales
print("Métriques globales :")
print(classification_report(Y_global, Y_global_pred))
# Out:
# Métriques pour le train set :
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    190942
#            1       0.79      0.55      0.65      5071
#
#     accuracy                           0.98    196013
#    macro avg       0.89      0.77      0.82    196013
# weighted avg       0.98      0.98      0.98    196013
# Métriques pour le test set :
#               precision    recall  f1-score   support
#
#            0     0.9882    0.9954    0.9918     47728
#            1     0.7635    0.5541    0.6421      1276
#
#     accuracy                         0.9839     49004
#    macro avg     0.8758    0.7747    0.8170     49004
# weighted avg     0.9823    0.9839    0.9827     49004
# Métriques globales :
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    238670
#            1       0.78      0.55      0.65      6347
#
#     accuracy                           0.98    245017
#    macro avg       0.89      0.77      0.82    245017
# weighted avg       0.98      0.98      0.98    245017

# %%
print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# f1-score on train set :  0.7673702396154135
# f1-score on test set :  0.7562069997008675

# %%
from sklearn.ensemble import (
    BaggingClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier,
    VotingClassifier,
    StackingClassifier,
)
from xgboost import XGBClassifier

# import base estimators
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    ConfusionMatrixDisplay,
    RocCurveDisplay,
)

# %% [markdown]
# ## Performance assessment

# %%
import xgboost as xgb
import optuna
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, classification_report
from sklearn.model_selection import GridSearchCV, train_test_split
from tqdm import tqdm

# Supposons que X_train, X_test, Y_train, Y_test sont déjà définis

# Étape 1 : GridSearchCV simple
xgb_model = xgb.XGBClassifier(
    eval_metric="logloss",
    random_state=42
)

param_grid = {
    "n_estimators": [100, 200],
    "max_depth": [3, 5],
    "learning_rate": [0.1, 0.2]
}

print("\n🔍 Lancement de GridSearchCV...")
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=3,
    scoring="f1_macro",
    verbose=0,
    n_jobs=-1
)
grid_search.fit(X_train, Y_train)
print("✅ GridSearch terminé!")
print("Meilleurs paramètres:", grid_search.best_params_)

# Étape 2 : Optuna (autour de la grille)
def objective(trial):
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 300, step=50),
        "max_depth": trial.suggest_int("max_depth", 3, 8),
        "learning_rate": trial.suggest_float("learning_rate", 0.05, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 2),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 2),
        "reg_lambda": trial.suggest_float("reg_lambda", 0, 2),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "eval_metric": "logloss",
        "random_state": 42,
    }
    model = xgb.XGBClassifier(**param)
    model.fit(X_train, Y_train)
    preds = model.predict(X_test)
    return f1_score(Y_test, preds, average="macro")

print("\n🎯 Début de l'optimisation Optuna...")
study = optuna.create_study(direction="maximize")
with tqdm(total=30, desc="Optuna Trials") as pbar:
    def tqdm_callback(study, trial):
        pbar.update(1)
    study.optimize(objective, n_trials=30, callbacks=[tqdm_callback])
print("✅ Optuna terminé!")
print("Meilleurs paramètres Optuna:", study.best_params)

# Étape 3 : Modèle final avec les meilleurs paramètres
final_params = dict(study.best_params)
final_params.update({"eval_metric": "logloss", "random_state": 42})
final_model = xgb.XGBClassifier(**final_params)
final_model.fit(X_train, Y_train)

# Étape 4 : Évaluation
print("\n📊 Évaluation du modèle final")
y_train_pred = final_model.predict(X_train)
y_test_pred = final_model.predict(X_test)
y_global_true = np.concatenate([Y_train, Y_test])
y_global_pred = np.concatenate([y_train_pred, y_test_pred])

# Fonctions d'affichage
def display_metrics(y_true, y_pred, title):
    print(f"\n🔹 {title}")
    print("Accuracy:", np.mean(y_true == y_pred))
    print("F1 macro:", f1_score(y_true, y_pred, average="macro"))
    print("F1 weighted:", f1_score(y_true, y_pred, average="weighted"))
    print(classification_report(y_true, y_pred, digits=4))  # Afficher 4 décimales
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap="Blues")
    plt.title(title)
    plt.show()

# Résultats
display_metrics(Y_train, y_train_pred, "Train Set")
display_metrics(Y_test, y_test_pred, "Test Set")
display_metrics(y_global_true, y_global_pred, "Global Set")

# Résumé F1
print("\n🎯 Résumé F1:")
print(f"F1 Score Train Set : {f1_score(Y_train, y_train_pred, average='macro'):.4f}")
print(f"F1 Score Test Set  : {f1_score(Y_test, y_test_pred, average='macro'):.4f}")
# Out:
# 🔍 Lancement de GridSearchCV...
# [I 2025-08-04 18:07:43,948] A new study created in memory with name: no-name-5d96a14c-36f9-413b-ad45-3a38c707f9f7
# ✅ GridSearch terminé!
# Meilleurs paramètres: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#
# 🎯 Début de l'optimisation Optuna...
# Optuna Trials:   0%|          | 0/30 [00:00<?, ?it/s][I 2025-08-04 18:07:44,571] Trial 0 finished with value: 0.8170992236207562 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.09776290812264733, 'subsample': 0.9874338398814404, 'colsample_bytree': 0.7890695394668304, 'gamma': 1.0106953807841392, 'reg_alpha': 0.20664396361138904, 'reg_lambda': 0.3125126541670362, 'min_child_weight': 2}. Best is trial 0 with value: 0.8170992236207562.
# Optuna Trials:   3%|▎         | 1/30 [00:00<00:18,  1.61it/s][I 2025-08-04 18:07:44,977] Trial 1 finished with value: 0.8202596434777608 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.155476910851165, 'subsample': 0.8656410127885672, 'colsample_bytree': 0.7071798517371857, 'gamma': 0.8642905013790507, 'reg_alpha': 1.3888352673430375, 'reg_lambda': 0.8521966413425293, 'min_child_weight': 8}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:   7%|▋         | 2/30 [00:01<00:13,  2.02it/s][I 2025-08-04 18:07:45,261] Trial 2 finished with value: 0.8148369405766758 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.24863905158740168, 'subsample': 0.7605011783393119, 'colsample_bytree': 0.7034549790011997, 'gamma': 1.1597490903627754, 'reg_alpha': 1.2075598765808275, 'reg_lambda': 0.22282308051389887, 'min_child_weight': 2}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  10%|█         | 3/30 [00:01<00:10,  2.51it/s][I 2025-08-04 18:07:45,676] Trial 3 finished with value: 0.8175646199983113 and parameters: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.16251492894920377, 'subsample': 0.8156284224467033, 'colsample_bytree': 0.6172226451536593, 'gamma': 1.673671646838943, 'reg_alpha': 0.8181257212498518, 'reg_lambda': 0.012902323288738193, 'min_child_weight': 1}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  13%|█▎        | 4/30 [00:01<00:10,  2.47it/s][I 2025-08-04 18:07:46,403] Trial 4 finished with value: 0.8183999919724496 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.09808170810093043, 'subsample': 0.8897630076579139, 'colsample_bytree': 0.8092382246600436, 'gamma': 1.0773530561047453, 'reg_alpha': 1.1799538338208175, 'reg_lambda': 1.6044757743437619, 'min_child_weight': 1}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  17%|█▋        | 5/30 [00:02<00:13,  1.92it/s][I 2025-08-04 18:07:47,414] Trial 5 finished with value: 0.8161415136407069 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.2870340585574941, 'subsample': 0.6179367118230036, 'colsample_bytree': 0.6796658284734348, 'gamma': 0.41193876047180633, 'reg_alpha': 0.39696487209987286, 'reg_lambda': 0.2868023700504052, 'min_child_weight': 7}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  20%|██        | 6/30 [00:03<00:16,  1.45it/s][I 2025-08-04 18:07:47,934] Trial 6 finished with value: 0.8195361632874685 and parameters: {'n_estimators': 250, 'max_depth': 7, 'learning_rate': 0.2684300357243097, 'subsample': 0.793941417754793, 'colsample_bytree': 0.7924674007597114, 'gamma': 1.753580755624438, 'reg_alpha': 0.48856288375700396, 'reg_lambda': 0.19436739270163605, 'min_child_weight': 5}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  23%|██▎       | 7/30 [00:03<00:14,  1.58it/s][I 2025-08-04 18:07:48,229] Trial 7 finished with value: 0.8171547178371535 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.18319272910740875, 'subsample': 0.9860263937715732, 'colsample_bytree': 0.8428575143119735, 'gamma': 0.7273648280845861, 'reg_alpha': 0.49449751192800595, 'reg_lambda': 1.1331585569472697, 'min_child_weight': 10}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  27%|██▋       | 8/30 [00:04<00:11,  1.90it/s][I 2025-08-04 18:07:49,085] Trial 8 finished with value: 0.8111066084460582 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.28824322246245815, 'subsample': 0.8998608347221331, 'colsample_bytree': 0.9041573173161637, 'gamma': 0.5590606192413798, 'reg_alpha': 0.44317176779515566, 'reg_lambda': 0.6925095264175491, 'min_child_weight': 3}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  30%|███       | 9/30 [00:05<00:13,  1.59it/s][I 2025-08-04 18:07:50,017] Trial 9 finished with value: 0.8170266019140617 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.15069366732565198, 'subsample': 0.8728883330782804, 'colsample_bytree': 0.7702687957742594, 'gamma': 0.3884378407737772, 'reg_alpha': 1.1861881996134485, 'reg_lambda': 1.0284962479749733, 'min_child_weight': 9}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  33%|███▎      | 10/30 [00:06<00:14,  1.38it/s][I 2025-08-04 18:07:50,749] Trial 10 finished with value: 0.8194820671811289 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.05168982489944676, 'subsample': 0.6730145361409806, 'colsample_bytree': 0.9927936015724583, 'gamma': 1.4274178628967173, 'reg_alpha': 1.8173882282504288, 'reg_lambda': 1.960030377699631, 'min_child_weight': 7}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  37%|███▋      | 11/30 [00:06<00:13,  1.38it/s][I 2025-08-04 18:07:51,925] Trial 11 finished with value: 0.815507741639312 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.22035334114416852, 'subsample': 0.7511041161255125, 'colsample_bytree': 0.7135735291916998, 'gamma': 0.0053949028854261005, 'reg_alpha': 1.686825648660134, 'reg_lambda': 0.709379910739865, 'min_child_weight': 5}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  40%|████      | 12/30 [00:07<00:15,  1.16it/s][I 2025-08-04 18:07:52,538] Trial 12 finished with value: 0.8185324909247673 and parameters: {'n_estimators': 250, 'max_depth': 6, 'learning_rate': 0.21281897061626828, 'subsample': 0.809700078761368, 'colsample_bytree': 0.6006222121594404, 'gamma': 1.926535504046812, 'reg_alpha': 0.7978321487776339, 'reg_lambda': 0.6423800833295602, 'min_child_weight': 5}. Best is trial 1 with value: 0.8202596434777608.
# Optuna Trials:  43%|████▎     | 13/30 [00:08<00:13,  1.27it/s][I 2025-08-04 18:07:53,040] Trial 13 finished with value: 0.821057192428907 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.13426913698779402, 'subsample': 0.7304648738637647, 'colsample_bytree': 0.8531501809525528, 'gamma': 1.4778092638323506, 'reg_alpha': 1.546503526532587, 'reg_lambda': 1.3623253451525232, 'min_child_weight': 7}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  47%|████▋     | 14/30 [00:09<00:11,  1.43it/s][I 2025-08-04 18:07:53,682] Trial 14 finished with value: 0.819171916776545 and parameters: {'n_estimators': 150, 'max_depth': 8, 'learning_rate': 0.12341475206189494, 'subsample': 0.7027910788196025, 'colsample_bytree': 0.8899936268931973, 'gamma': 0.765417623375924, 'reg_alpha': 1.6261679001092213, 'reg_lambda': 1.4410024964548644, 'min_child_weight': 8}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  50%|█████     | 15/30 [00:09<00:10,  1.46it/s][I 2025-08-04 18:07:54,242] Trial 15 finished with value: 0.8197919429430683 and parameters: {'n_estimators': 150, 'max_depth': 6, 'learning_rate': 0.13091560010889658, 'subsample': 0.7095598629345421, 'colsample_bytree': 0.9545733143879114, 'gamma': 1.2369972825836135, 'reg_alpha': 1.4864184863767214, 'reg_lambda': 1.305010133019836, 'min_child_weight': 7}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  53%|█████▎    | 16/30 [00:10<00:09,  1.55it/s][I 2025-08-04 18:07:54,681] Trial 16 finished with value: 0.8166456362152847 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.1922945797706561, 'subsample': 0.9337152973273506, 'colsample_bytree': 0.7401443385256253, 'gamma': 1.464323187700595, 'reg_alpha': 1.9663953840370831, 'reg_lambda': 1.684282851748852, 'min_child_weight': 10}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  57%|█████▋    | 17/30 [00:10<00:07,  1.71it/s][I 2025-08-04 18:07:55,138] Trial 17 finished with value: 0.81898682355383 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.08411741880882612, 'subsample': 0.6447434196534154, 'colsample_bytree': 0.6599478441906569, 'gamma': 1.3982216604916624, 'reg_alpha': 1.4255948047986935, 'reg_lambda': 0.9278947725754527, 'min_child_weight': 8}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  60%|██████    | 18/30 [00:11<00:06,  1.83it/s][I 2025-08-04 18:07:55,657] Trial 18 finished with value: 0.8191883851976299 and parameters: {'n_estimators': 150, 'max_depth': 8, 'learning_rate': 0.13476694711182116, 'subsample': 0.85249092251834, 'colsample_bytree': 0.8568894415166087, 'gamma': 0.8331062526837287, 'reg_alpha': 1.4109370150987188, 'reg_lambda': 1.2433879067825346, 'min_child_weight': 6}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  63%|██████▎   | 19/30 [00:11<00:05,  1.86it/s][I 2025-08-04 18:07:56,553] Trial 19 finished with value: 0.8171656820825386 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.05929802060758113, 'subsample': 0.8399554532267235, 'colsample_bytree': 0.7468789993958661, 'gamma': 0.0761516001810989, 'reg_alpha': 0.9492332768794536, 'reg_lambda': 0.8979362169020324, 'min_child_weight': 4}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  67%|██████▋   | 20/30 [00:12<00:06,  1.55it/s][I 2025-08-04 18:07:57,215] Trial 20 finished with value: 0.8187283047528402 and parameters: {'n_estimators': 250, 'max_depth': 4, 'learning_rate': 0.2055980140536691, 'subsample': 0.76088381526686, 'colsample_bytree': 0.8325199179416816, 'gamma': 1.2623784811389336, 'reg_alpha': 1.979767374582219, 'reg_lambda': 1.9237593155631456, 'min_child_weight': 8}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  70%|███████   | 21/30 [00:13<00:05,  1.54it/s][I 2025-08-04 18:07:57,728] Trial 21 finished with value: 0.8207074888978315 and parameters: {'n_estimators': 150, 'max_depth': 6, 'learning_rate': 0.13534517858577066, 'subsample': 0.7089693914360707, 'colsample_bytree': 0.9863771208574453, 'gamma': 1.6194272173509685, 'reg_alpha': 1.4457241800255052, 'reg_lambda': 1.330204098038143, 'min_child_weight': 7}. Best is trial 13 with value: 0.821057192428907.
# Optuna Trials:  73%|███████▎  | 22/30 [00:13<00:04,  1.64it/s][I 2025-08-04 18:07:58,255] Trial 22 finished with value: 0.8211968158678493 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.15869745622781098, 'subsample': 0.7199782879703587, 'colsample_bytree': 0.9330883568216186, 'gamma': 1.612680435212285, 'reg_alpha': 1.6065928641714784, 'reg_lambda': 1.5001307917557087, 'min_child_weight': 6}. Best is trial 22 with value: 0.8211968158678493.
# Optuna Trials:  77%|███████▋  | 23/30 [00:14<00:04,  1.71it/s][I 2025-08-04 18:07:58,682] Trial 23 finished with value: 0.8152513064526633 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.11504213277143442, 'subsample': 0.7030251042093374, 'colsample_bytree': 0.9426175172421456, 'gamma': 1.6383790371058764, 'reg_alpha': 1.6758976782576944, 'reg_lambda': 1.5432841701501758, 'min_child_weight': 6}. Best is trial 22 with value: 0.8211968158678493.
# Optuna Trials:  80%|████████  | 24/30 [00:14<00:03,  1.86it/s][I 2025-08-04 18:07:59,149] Trial 24 finished with value: 0.8213531598251695 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.17405043427804304, 'subsample': 0.7422581861918843, 'colsample_bytree': 0.995078735538474, 'gamma': 1.9212252096915283, 'reg_alpha': 1.8035630207098512, 'reg_lambda': 1.73849464358072, 'min_child_weight': 6}. Best is trial 24 with value: 0.8213531598251695.
# Optuna Trials:  83%|████████▎ | 25/30 [00:15<00:02,  1.94it/s][I 2025-08-04 18:07:59,526] Trial 25 finished with value: 0.8204240117894352 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.1750262738472731, 'subsample': 0.7373718144798909, 'colsample_bytree': 0.924060111074239, 'gamma': 1.986432270925607, 'reg_alpha': 1.769725479842787, 'reg_lambda': 1.737647258523178, 'min_child_weight': 4}. Best is trial 24 with value: 0.8213531598251695.
# Optuna Trials:  87%|████████▋ | 26/30 [00:15<00:01,  2.11it/s][I 2025-08-04 18:08:00,002] Trial 26 finished with value: 0.819935899020682 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.22866678745768385, 'subsample': 0.6629372688433821, 'colsample_bytree': 0.8871428744474075, 'gamma': 1.8111798325590058, 'reg_alpha': 1.8681098506585938, 'reg_lambda': 1.8260925738261082, 'min_child_weight': 6}. Best is trial 24 with value: 0.8213531598251695.
# Optuna Trials:  90%|█████████ | 27/30 [00:16<00:01,  2.11it/s][I 2025-08-04 18:08:00,579] Trial 27 finished with value: 0.8228822299114242 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.16613170775801966, 'subsample': 0.7841130548807231, 'colsample_bytree': 0.9587688143983789, 'gamma': 1.5311606434597302, 'reg_alpha': 1.5506358820324064, 'reg_lambda': 1.47294234802377, 'min_child_weight': 4}. Best is trial 27 with value: 0.8228822299114242.
# Optuna Trials:  93%|█████████▎| 28/30 [00:16<00:01,  1.98it/s][I 2025-08-04 18:08:01,143] Trial 28 finished with value: 0.8233451620841412 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.19331492771305284, 'subsample': 0.7880463407935493, 'colsample_bytree': 0.978210856255207, 'gamma': 1.8426080046080429, 'reg_alpha': 1.296223769891142, 'reg_lambda': 1.5113509861308871, 'min_child_weight': 4}. Best is trial 28 with value: 0.8233451620841412.
# Optuna Trials:  97%|█████████▋| 29/30 [00:17<00:00,  1.91it/s][I 2025-08-04 18:08:01,693] Trial 29 finished with value: 0.8206125008828984 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.19803934062808115, 'subsample': 0.7845493235504376, 'colsample_bytree': 0.9595959419267798, 'gamma': 1.8738631474955905, 'reg_alpha': 1.3090754184194617, 'reg_lambda': 1.7298034233377189, 'min_child_weight': 3}. Best is trial 28 with value: 0.8233451620841412.
# Optuna Trials: 100%|██████████| 30/30 [00:17<00:00,  1.69it/s]
# ✅ Optuna terminé!
# Meilleurs paramètres Optuna: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.19331492771305284, 'subsample': 0.7880463407935493, 'colsample_bytree': 0.978210856255207, 'gamma': 1.8426080046080429, 'reg_alpha': 1.296223769891142, 'reg_lambda': 1.5113509861308871, 'min_child_weight': 4}
#
# 📊 Évaluation du modèle final
#
# 🔹 Train Set
# Accuracy: 0.9844091973491554
# F1 macro: 0.8211850455015691
# F1 weighted: 0.9831872365705578
#               precision    recall  f1-score   support
#
#            0     0.9884    0.9957    0.9920    190942
#            1     0.7746    0.5604    0.6503      5071
#
#     accuracy                         0.9844    196013
#    macro avg     0.8815    0.7781    0.8212    196013
# weighted avg     0.9829    0.9844    0.9832    196013
# 🔹 Test Set
# Accuracy: 0.9842053709901233
# F1 macro: 0.8233451620841412
# F1 weighted: 0.9831389780907421
#               precision    recall  f1-score   support
#
#            0     0.9887    0.9951    0.9919     47728
#            1     0.7598    0.5752    0.6548      1276
#
#     accuracy                         0.9842     49004
#    macro avg     0.8743    0.7852    0.8233     49004
# weighted avg     0.9828    0.9842    0.9831     49004
# 🔹 Global Set
# Accuracy: 0.9843684315782171
# F1 macro: 0.8216262695981122
# F1 weighted: 0.9831779490379562
#               precision    recall  f1-score   support
#
#            0     0.9885    0.9956    0.9920    238670
#            1     0.7715    0.5634    0.6512      6347
#
#     accuracy                         0.9844    245017
#    macro avg     0.8800    0.7795    0.8216    245017
# weighted avg     0.9829    0.9844    0.9832    245017
# 🎯 Résumé F1:
# F1 Score Train Set : 0.8212
# F1 Score Test Set  : 0.8233

# %%
print("f1-score on train set : ", f1_score(Y_train, y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, y_test_pred))
# Out:
# f1-score on train set :  0.7699551569506726
# f1-score on test set :  0.7610566933808252

# %% [markdown]
# 🎯 Quand Utiliser Quoi ?
#
# ## Utilisez GridSearchCV quand :
#
# 🔹 Peu de paramètres (< 4-5 hyperparamètres)
# 🔹 Espace de recherche petit (< 100 combinaisons)
# 🔹 Reproductibilité critique
# 🔹 Recherche exhaustive nécessaire
# 🔹 Première approche/baseline
#
# Exemple : 2-3 hyperparamètres avec quelques valeurs chacun
#
# ## Utilisez Optuna quand :
#
# 🔸 Beaucoup de paramètres (> 5 hyperparamètres)
# 🔸 Espace de recherche large
# 🔸 Budget temps limité
# 🔸 Hyperparamètres continus (learning_rate, regularization)
# 🔸 Optimisation avancée
#
# Exemple : Deep Learning, ensembles complexes, AutoML

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Supposons que X_train, X_test, Y_train, Y_test soient déjà définis et prétraités

# Meilleurs paramètres obtenus (exemple)
best_params = {
    'max_depth': 3,
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200,
}

# Construire le modèle avec les meilleurs paramètres
model = GradientBoostingClassifier(**best_params)

# Entraîner le modèle
model.fit(X_train, Y_train)

# Fonction pour afficher la matrice de confusion et les métriques
def plot_confusion_matrix(Y_true, Y_pred, title):
    cm = confusion_matrix(Y_true, Y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(title)
    plt.show()
    print(classification_report(Y_true, Y_pred))

# Prédictions sur l'ensemble d'entraînement
Y_train_pred = model.predict(X_train)
plot_confusion_matrix(Y_train, Y_train_pred, "Training Set Confusion Matrix")

# Prédictions sur l'ensemble de test
Y_test_pred = model.predict(X_test)
plot_confusion_matrix(Y_test, Y_test_pred, "Test Set Confusion Matrix")

# Convertir les ensembles numpy en DataFrames pandas pour l'ensemble global
X_train_df = pd.DataFrame(X_train)
X_test_df = pd.DataFrame(X_test)
Y_train_series = pd.Series(Y_train)
Y_test_series = pd.Series(Y_test)

# Combiner les ensembles d'entraînement et de test
X_global = pd.concat([X_train_df, X_test_df], axis=0)
Y_global = pd.concat([Y_train_series, Y_test_series], axis=0)

# Prédictions sur l'ensemble global
Y_global_pred = model.predict(X_global)
plot_confusion_matrix(Y_global, Y_global_pred, "Global Confusion Matrix")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    220334
#            1       0.86      0.69      0.77      7330
#
#     accuracy                           0.99    227664
#    macro avg       0.92      0.84      0.88    227664
# weighted avg       0.99      0.99      0.99    227664
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     55066
#            1       0.85      0.68      0.76      1850
#
#     accuracy                           0.99     56916
#    macro avg       0.92      0.84      0.87     56916
# weighted avg       0.98      0.99      0.98     56916
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    275400
#            1       0.85      0.69      0.76      9180
#
#     accuracy                           0.99    284580
#    macro avg       0.92      0.84      0.88    284580
# weighted avg       0.99      0.99      0.99    284580

# %%
# WARNING : Use the same score as the one that will be used by Kaggle !
# Here, the f1-score will be used to assess the performances on the leaderboard
print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# f1-score on train set :  0.7615141531634505
# f1-score on test set :  0.7678464307138573

# %%
import optuna
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, ParameterGrid
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, classification_report
from tqdm.notebook import tqdm
import time
import numpy as np
from sklearn.base import clone

# Supposons que X_train, X_test, Y_train, Y_test soient déjà définis

# SOLUTION: Wrapper pour GridSearchCV avec tqdm
class TqdmGridSearchCV:
    def __init__(self, estimator, param_grid, cv=5, scoring=None, n_jobs=1):
        self.estimator = estimator
        self.param_grid = param_grid
        self.cv = cv
        self.scoring = scoring
        self.n_jobs = n_jobs
        self.best_params_ = None
        self.best_score_ = None
        self.best_estimator_ = None
        self.cv_results_ = {}
        
    def fit(self, X, y):
        # Créer la grille de paramètres
        param_list = list(ParameterGrid(self.param_grid))
        
        results = []
        best_score = -np.inf
        best_params = None
        best_estimator = None
        
        # Barre de progression avec tqdm
        with tqdm(total=len(param_list), desc="🔍 XGBoost GridSearch") as pbar:
            for i, params in enumerate(param_list):
                # Cloner l'estimateur et définir les paramètres
                estimator = clone(self.estimator)
                estimator.set_params(**params)
                
                # Validation croisée
                scores = cross_val_score(estimator, X, y, cv=self.cv, scoring=self.scoring, n_jobs=1)
                mean_score = scores.mean()
                std_score = scores.std()
                
                # Stocker les résultats
                results.append({
                    'params': params,
                    'mean_test_score': mean_score,
                    'std_test_score': std_score,
                    'rank_test_score': 0  # Sera calculé après
                })
                
                # Mettre à jour le meilleur
                if mean_score > best_score:
                    best_score = mean_score
                    best_params = params
                    # Entraîner le meilleur estimateur sur toutes les données
                    best_estimator = clone(self.estimator)
                    best_estimator.set_params(**params)
                    best_estimator.fit(X, y)
                
                # Mettre à jour la barre de progression
                pbar.set_postfix({
                    'Current': f'{mean_score:.4f}',
                    'Best': f'{best_score:.4f}',
                    'Params': f'{i+1}/{len(param_list)}'
                })
                pbar.update(1)
        
        # Calculer les rangs
        results.sort(key=lambda x: x['mean_test_score'], reverse=True)
        for i, result in enumerate(results):
            result['rank_test_score'] = i + 1
        
        # Stocker les résultats
        self.best_score_ = best_score
        self.best_params_ = best_params
        self.best_estimator_ = best_estimator
        self.cv_results_ = {
            'params': [r['params'] for r in results],
            'mean_test_score': [r['mean_test_score'] for r in results],
            'std_test_score': [r['std_test_score'] for r in results],
            'rank_test_score': [r['rank_test_score'] for r in results]
        }
        
        return self
    
    def predict(self, X):
        return self.best_estimator_.predict(X)
    
    def score(self, X, y):
        return self.best_estimator_.score(X, y)

# Utilisation du wrapper avec XGBoost
print("\n" + "="*60)
print("🚀 XGBoost GridSearch avec barre de progression tqdm")
print("="*60)

# Définir le modèle XGBoost
model = xgb.XGBClassifier(
    random_state=42,
    eval_metric='logloss',  # Évite les warnings
    verbosity=0  # Réduit les sorties
)

# Paramètres spécifiques à XGBoost pour GridSearch
params = {
    "n_estimators": [100, 200, 300],
    "max_depth": [3, 4, 6],
    "learning_rate": [0.1, 0.2, 0.3],
    "subsample": [0.8, 0.9, 1.0],
}

print(f"Paramètres XGBoost à tester: {params}")
total_combinations = np.prod([len(v) for v in params.values()])
print(f"Total de combinaisons: {total_combinations}")

# Utiliser notre wrapper avec tqdm
tqdm_gridsearch = TqdmGridSearchCV(
    estimator=model,
    param_grid=params,
    cv=3,
    scoring='accuracy'
)

print("🔍 Démarrage de XGBoost GridSearch avec tqdm...")
tqdm_gridsearch.fit(X_train, Y_train)

print("\n✅ XGBoost GridSearch terminé!")
print(f"Meilleurs paramètres: {tqdm_gridsearch.best_params_}")
print(f"Meilleur score CV: {tqdm_gridsearch.best_score_:.4f}")
print(f"Score sur train: {tqdm_gridsearch.score(X_train, Y_train):.4f}")
print(f"Score sur test: {tqdm_gridsearch.score(X_test, Y_test):.4f}")

# Utilisation des résultats de GridSearch pour orienter Optuna
print(f"\n🔗 Utilisation des résultats GridSearch pour optimiser Optuna...")
print(f"Meilleurs paramètres GridSearch: {tqdm_gridsearch.best_params_}")

# Définir des ranges pour Optuna basés sur GridSearch
best_grid_params = tqdm_gridsearch.best_params_

# Optuna avec tqdm (votre partie originale)
print("\n" + "="*60)
print("🎯 Optuna avec barre de progression")
print("="*60)

class OptunaTqdmCallback:
    def __init__(self, n_trials):
        self.n_trials = n_trials
        self.pbar = None
        
    def __call__(self, study, trial):
        if self.pbar is None:
            self.pbar = tqdm(total=self.n_trials, desc="🔍 XGBoost Optuna Optimization")
        
        self.pbar.update(1)
        best_value = study.best_value if study.best_value else 0
        self.pbar.set_postfix({
            'Current F1': f'{trial.value:.4f}',
            'Best F1': f'{best_value:.4f}',
        })
        
        if trial.number + 1 >= self.n_trials:
            self.pbar.close()

def objective(trial):
    # Utiliser les résultats de GridSearch pour définir des ranges intelligents
    # autour des meilleurs paramètres trouvés
    
    # Définir les ranges basés sur les meilleurs paramètres GridSearch
    best_n_estimators = best_grid_params['n_estimators']
    best_max_depth = best_grid_params['max_depth']
    best_learning_rate = best_grid_params['learning_rate']
    best_subsample = best_grid_params['subsample']
    
    param = {
        # Exploration autour des meilleurs valeurs GridSearch avec plus de granularité
        'n_estimators': trial.suggest_int('n_estimators', 
                                        max(50, best_n_estimators - 100), 
                                        best_n_estimators + 200, 
                                        step=50),
        'max_depth': trial.suggest_int('max_depth', 
                                     max(2, best_max_depth - 1), 
                                     min(10, best_max_depth + 3)),
        'learning_rate': trial.suggest_float('learning_rate', 
                                           max(0.01, best_learning_rate - 0.1), 
                                           min(0.5, best_learning_rate + 0.2)),
        'subsample': trial.suggest_float('subsample', 
                                       max(0.5, best_subsample - 0.2), 
                                       min(1.0, best_subsample + 0.1)),
        # Ajouter des paramètres spécifiques XGBoost que GridSearch n'a pas explorés
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 2),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 2),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 2),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        # Paramètres fixes
        'random_state': 42,
        'eval_metric': 'logloss',
        'verbosity': 0
    }
    
    model = xgb.XGBClassifier(**param)
    model.fit(X_train, Y_train)
    predictions = model.predict(X_test)
    f1 = f1_score(Y_test, predictions, average='macro')
    return f1

# Optimisation Optuna guidée par GridSearch
print("🎯 Optuna avec recherche guidée par GridSearch")
print("="*60)
print(f"🎯 Exploration fine autour de: {best_grid_params}")
print(f"➕ Ajout de nouveaux paramètres XGBoost: colsample_bytree, gamma, reg_alpha, reg_lambda, min_child_weight")

n_trials = 50  # Plus d'essais pour l'optimisation fine
study = optuna.create_study(direction='maximize')
callback = OptunaTqdmCallback(n_trials)
study.optimize(objective, n_trials=n_trials, callbacks=[callback])

print(f"\n✅ Optimisation hybride XGBoost terminée!")
print(f"Amélioration: {study.best_value:.4f} vs {tqdm_gridsearch.best_score_:.4f} (GridSearch)")
improvement = study.best_value - tqdm_gridsearch.best_score_
print(f"Gain de performance: {improvement:.4f} ({improvement*100:.2f}%)")

print(f"\n🔧 Paramètres finaux XGBoost optimisés:")
for key, value in study.best_params.items():
    if key in best_grid_params:
        print(f"  • {key}: {value} (GridSearch: {best_grid_params[key]})")
    else:
        print(f"  • {key}: {value} (nouveau paramètre)")

# Modèle final combinant les deux approches
final_model = xgb.XGBClassifier(**study.best_params)
final_model.fit(X_train, Y_train)

y_pred_grid = tqdm_gridsearch.predict(X_test)
y_pred_final = final_model.predict(X_test)

print(f"\n🎯 F1 SCORES SUR LE TEST SET:")
print(f"GridSearch seul:     {f1_score(Y_test, y_pred_grid, average='macro'):.4f}")
print(f"Approche hybride:    {f1_score(Y_test, y_pred_final, average='macro'):.4f}")

print(f"\n🎯 ACCURACY SUR LE TEST SET:")
print(f"GridSearch seul:     {tqdm_gridsearch.score(X_test, Y_test):.4f}")
print(f"Approche hybride:    {final_model.score(X_test, Y_test):.4f}")

# Matrices de confusion et métriques complètes
print("\n" + "="*60)
print("📊 MATRICES DE CONFUSION - APPROCHE HYBRIDE XGBOOST")
print("="*60)

# Prédictions pour les deux approches
y_train_pred_grid = tqdm_gridsearch.predict(X_train)
y_test_pred_grid = tqdm_gridsearch.predict(X_test)
y_train_pred_final = final_model.predict(X_train)
y_test_pred_final = final_model.predict(X_test)

# Configuration des graphiques
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Matrices de Confusion XGBoost - GridSearch vs Approche Hybride (GridSearch + Optuna)', fontsize=16, fontweight='bold')

# GridSearch seul - Train Set
cm_grid_train = confusion_matrix(Y_train, y_train_pred_grid)
disp_grid_train = ConfusionMatrixDisplay(confusion_matrix=cm_grid_train)
disp_grid_train.plot(ax=axes[0,0], cmap='Blues')
axes[0,0].set_title('XGBoost GridSearch seul - Train Set')

# GridSearch seul - Test Set  
cm_grid_test = confusion_matrix(Y_test, y_test_pred_grid)
disp_grid_test = ConfusionMatrixDisplay(confusion_matrix=cm_grid_test)
disp_grid_test.plot(ax=axes[0,1], cmap='Blues')
axes[0,1].set_title('XGBoost GridSearch seul - Test Set')

# Approche hybride - Train Set
cm_final_train = confusion_matrix(Y_train, y_train_pred_final)
disp_final_train = ConfusionMatrixDisplay(confusion_matrix=cm_final_train)
disp_final_train.plot(ax=axes[1,0], cmap='Greens')
axes[1,0].set_title('XGBoost Approche Hybride - Train Set')

# Approche hybride - Test Set
cm_final_test = confusion_matrix(Y_test, y_test_pred_final)
disp_final_test = ConfusionMatrixDisplay(confusion_matrix=cm_final_test)
disp_final_test.plot(ax=axes[1,1], cmap='Greens')
axes[1,1].set_title('XGBoost Approche Hybride - Test Set')

plt.tight_layout()
plt.show()

# Métriques détaillées
print("📈 MÉTRIQUES DÉTAILLÉES XGBOOST")
print("=" * 50)

print("\n🔹 XGBOOST GRIDSEARCH SEUL - TRAIN SET:")
print(f"Accuracy: {tqdm_gridsearch.score(X_train, Y_train):.4f}")
print(f"F1 Score (macro): {f1_score(Y_train, y_train_pred_grid, average='macro'):.4f}")
print(f"F1 Score (weighted): {f1_score(Y_train, y_train_pred_grid, average='weighted'):.4f}")
print("\nClassification Report:")
print(classification_report(Y_train, y_train_pred_grid))

print("\n🔹 XGBOOST GRIDSEARCH SEUL - TEST SET:")
print(f"Accuracy: {tqdm_gridsearch.score(X_test, Y_test):.4f}")
print(f"F1 Score (macro): {f1_score(Y_test, y_test_pred_grid, average='macro'):.4f}")
print(f"F1 Score (weighted): {f1_score(Y_test, y_test_pred_grid, average='weighted'):.4f}")
print("\nClassification Report:")
print(classification_report(Y_test, y_test_pred_grid))

print("\n🔸 XGBOOST APPROCHE HYBRIDE - TRAIN SET:")
print(f"Accuracy: {final_model.score(X_train, Y_train):.4f}")
print(f"F1 Score (macro): {f1_score(Y_train, y_train_pred_final, average='macro'):.4f}")
print(f"F1 Score (weighted): {f1_score(Y_train, y_train_pred_final, average='weighted'):.4f}")
print("\nClassification Report:")
print(classification_report(Y_train, y_train_pred_final))

print("\n🔸 XGBOOST APPROCHE HYBRIDE - TEST SET:")
print(f"Accuracy: {final_model.score(X_test, Y_test):.4f}")
print(f"F1 Score (macro): {f1_score(Y_test, y_test_pred_final, average='macro'):.4f}")
print(f"F1 Score (weighted): {f1_score(Y_test, y_test_pred_final, average='weighted'):.4f}")
print("\nClassification Report:")
print(classification_report(Y_test, y_test_pred_final))

# Résumé comparatif
print("\n" + "="*60)
print("📊 RÉSUMÉ COMPARATIF XGBOOST")
print("="*60)

results_summary = {
    'Approche': ['XGB GridSearch', 'XGB GridSearch', 'XGB Hybride', 'XGB Hybride'],
    'Dataset': ['Train', 'Test', 'Train', 'Test'],
    'Accuracy': [
        tqdm_gridsearch.score(X_train, Y_train),
        tqdm_gridsearch.score(X_test, Y_test),
        final_model.score(X_train, Y_train),
        final_model.score(X_test, Y_test)
    ],
    'F1 Macro': [
        f1_score(Y_train, y_train_pred_grid, average='macro'),
        f1_score(Y_test, y_test_pred_grid, average='macro'),
        f1_score(Y_train, y_train_pred_final, average='macro'),
        f1_score(Y_test, y_test_pred_final, average='macro')
    ]
}

print(f"{'Approche':<15} {'Dataset':<8} {'Accuracy':<10} {'F1 Macro':<10}")
print("-" * 50)
for i in range(len(results_summary['Approche'])):
    print(f"{results_summary['Approche'][i]:<15} {results_summary['Dataset'][i]:<8} "
          f"{results_summary['Accuracy'][i]:<10.4f} {results_summary['F1 Macro'][i]:<10.4f}")

print("\n🎉 Optimisation hybride XGBoost complète terminée!")
print("🔗 GridSearch a fourni une base solide avec les paramètres principaux")  
print("🎯 Optuna a affiné et ajouté les paramètres de régularisation avancés")
print("🚀 Le modèle XGBoost final combine le meilleur des deux approches!")
# Out:
# ============================================================
# 🚀 XGBoost GridSearch avec barre de progression tqdm
# ============================================================
# Paramètres XGBoost à tester: {'n_estimators': [100, 200, 300], 'max_depth': [3, 4, 6], 'learning_rate': [0.1, 0.2, 0.3], 'subsample': [0.8, 0.9, 1.0]}
# Total de combinaisons: 81
# 🔍 Démarrage de XGBoost GridSearch avec tqdm...
# 🔍 XGBoost GridSearch:   0%|          | 0/81 [00:00<?, ?it/s]
# [I 2025-08-04 09:06:32,154] A new study created in memory with name: no-name-45f772f4-1cac-41a7-9b74-a63d268ac14b
# ✅ XGBoost GridSearch terminé!
# Meilleurs paramètres: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0}
# Meilleur score CV: 0.9862
# Score sur train: 0.9864
# Score sur test: 0.9857
#
# 🔗 Utilisation des résultats GridSearch pour optimiser Optuna...
# Meilleurs paramètres GridSearch: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0}
#
# ============================================================
# 🎯 Optuna avec barre de progression
# ============================================================
# 🎯 Optuna avec recherche guidée par GridSearch
# ============================================================
# 🎯 Exploration fine autour de: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0}
# ➕ Ajout de nouveaux paramètres XGBoost: colsample_bytree, gamma, reg_alpha, reg_lambda, min_child_weight
# [I 2025-08-04 09:06:32,726] Trial 0 finished with value: 0.8750588320480793 and parameters: {'n_estimators': 150, 'max_depth': 6, 'learning_rate': 0.24096729428537747, 'subsample': 0.9828826376240714, 'colsample_bytree': 0.8506089976901514, 'gamma': 0.3403732338658776, 'reg_alpha': 1.8564295976903558, 'reg_lambda': 0.6540499883472004, 'min_child_weight': 6}. Best is trial 0 with value: 0.8750588320480793.
# 🔍 XGBoost Optuna Optimization:   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-08-04 09:06:33,221] Trial 1 finished with value: 0.8750317162797194 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.11699191429664262, 'subsample': 0.8201973775599922, 'colsample_bytree': 0.8200424274275377, 'gamma': 1.6862311646426102, 'reg_alpha': 0.7329894626404536, 'reg_lambda': 1.6358965964243652, 'min_child_weight': 1}. Best is trial 0 with value: 0.8750588320480793.
# [I 2025-08-04 09:06:34,048] Trial 2 finished with value: 0.8720161471897372 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.029561466279414195, 'subsample': 0.9620639031154252, 'colsample_bytree': 0.9473489508013699, 'gamma': 0.3553281953960581, 'reg_alpha': 0.014909903318301332, 'reg_lambda': 1.5736580603310892, 'min_child_weight': 2}. Best is trial 0 with value: 0.8750588320480793.
# [I 2025-08-04 09:06:35,161] Trial 3 finished with value: 0.8747585282404425 and parameters: {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.1683937963761619, 'subsample': 0.882635187081641, 'colsample_bytree': 0.8645803565624797, 'gamma': 0.4440078310619766, 'reg_alpha': 1.4757669579070596, 'reg_lambda': 0.9347184091656751, 'min_child_weight': 8}. Best is trial 0 with value: 0.8750588320480793.
# [I 2025-08-04 09:06:35,999] Trial 4 finished with value: 0.8742530688664867 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.07960578526980375, 'subsample': 0.9676655573603785, 'colsample_bytree': 0.8320950579566995, 'gamma': 1.1349225821527804, 'reg_alpha': 0.34109288786365966, 'reg_lambda': 0.5831018989609906, 'min_child_weight': 8}. Best is trial 0 with value: 0.8750588320480793.
# [I 2025-08-04 09:06:37,023] Trial 5 finished with value: 0.8752755670504633 and parameters: {'n_estimators': 250, 'max_depth': 5, 'learning_rate': 0.19359744424012681, 'subsample': 0.8116774725821249, 'colsample_bytree': 0.8942740877905768, 'gamma': 0.6581350164142619, 'reg_alpha': 1.2300621266843121, 'reg_lambda': 1.5191310395826374, 'min_child_weight': 5}. Best is trial 5 with value: 0.8752755670504633.
# [I 2025-08-04 09:06:37,412] Trial 6 finished with value: 0.874021202330302 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.24909603654001405, 'subsample': 0.9480551993720351, 'colsample_bytree': 0.6269570456718968, 'gamma': 0.6330692324798628, 'reg_alpha': 0.004993372622230208, 'reg_lambda': 1.2016733596074514, 'min_child_weight': 3}. Best is trial 5 with value: 0.8752755670504633.
# [I 2025-08-04 09:06:38,488] Trial 7 finished with value: 0.8759873195680853 and parameters: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.05580896384712171, 'subsample': 0.8724520840613256, 'colsample_bytree': 0.8219702549383303, 'gamma': 0.8327414779745037, 'reg_alpha': 0.6881302264493854, 'reg_lambda': 0.02893164825016936, 'min_child_weight': 3}. Best is trial 7 with value: 0.8759873195680853.
# [I 2025-08-04 09:06:39,293] Trial 8 finished with value: 0.874359037456701 and parameters: {'n_estimators': 250, 'max_depth': 2, 'learning_rate': 0.14523251208346633, 'subsample': 0.9274932895976868, 'colsample_bytree': 0.6293505106200326, 'gamma': 0.9647087333255964, 'reg_alpha': 1.8515835644608845, 'reg_lambda': 1.3823541966987214, 'min_child_weight': 10}. Best is trial 7 with value: 0.8759873195680853.
# [I 2025-08-04 09:06:39,655] Trial 9 finished with value: 0.8734317978807355 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2972998186993646, 'subsample': 0.8070109497951609, 'colsample_bytree': 0.8085175128684728, 'gamma': 1.4681032236936233, 'reg_alpha': 1.4292200453038038, 'reg_lambda': 0.1731904912257396, 'min_child_weight': 9}. Best is trial 7 with value: 0.8759873195680853.
# [I 2025-08-04 09:06:41,842] Trial 10 finished with value: 0.8768115822345708 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.02875028922122816, 'subsample': 0.8709192016187232, 'colsample_bytree': 0.7248389901334273, 'gamma': 1.9737671254200042, 'reg_alpha': 0.7396592148521877, 'reg_lambda': 0.10263305707848835, 'min_child_weight': 4}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:43,876] Trial 11 finished with value: 0.8764579226797276 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.021122268536234605, 'subsample': 0.8694958186662732, 'colsample_bytree': 0.71935820929389, 'gamma': 1.9515904672961808, 'reg_alpha': 0.765329573792217, 'reg_lambda': 0.04373662552414808, 'min_child_weight': 4}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:45,988] Trial 12 finished with value: 0.8746958739456074 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.016873258042125992, 'subsample': 0.8456428608114599, 'colsample_bytree': 0.7069199394675887, 'gamma': 1.8891738550307184, 'reg_alpha': 0.7816251673833081, 'reg_lambda': 0.36074486453068694, 'min_child_weight': 5}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:47,323] Trial 13 finished with value: 0.8755758949662448 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.08832844437910875, 'subsample': 0.9097050882566177, 'colsample_bytree': 0.7341076646843674, 'gamma': 1.9343205424872718, 'reg_alpha': 0.4470848028594281, 'reg_lambda': 0.40761758667988773, 'min_child_weight': 4}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:49,433] Trial 14 finished with value: 0.8724278101453469 and parameters: {'n_estimators': 350, 'max_depth': 6, 'learning_rate': 0.014122791015199443, 'subsample': 0.855227621045324, 'colsample_bytree': 0.7260358312128127, 'gamma': 1.3985451317002204, 'reg_alpha': 1.0735761765021608, 'reg_lambda': 1.8918919833600805, 'min_child_weight': 6}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:50,764] Trial 15 finished with value: 0.8759616907070373 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.06164395151990764, 'subsample': 0.8998310918454928, 'colsample_bytree': 0.6906851201359252, 'gamma': 1.6254427956218347, 'reg_alpha': 0.4192438714915572, 'reg_lambda': 0.007055497805880037, 'min_child_weight': 4}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:52,901] Trial 16 finished with value: 0.8734173603064275 and parameters: {'n_estimators': 350, 'max_depth': 6, 'learning_rate': 0.10348061640440567, 'subsample': 0.8476776627947985, 'colsample_bytree': 0.7639522683883317, 'gamma': 0.08703969138565193, 'reg_alpha': 1.0217751724697015, 'reg_lambda': 1.0014231824574558, 'min_child_weight': 7}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:54,283] Trial 17 finished with value: 0.8755827700872847 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.13563485388901644, 'subsample': 0.8791255333184105, 'colsample_bytree': 0.6608895424311382, 'gamma': 1.959089445960599, 'reg_alpha': 0.8320865174669585, 'reg_lambda': 0.28766400444369133, 'min_child_weight': 1}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:56,020] Trial 18 finished with value: 0.8759924445851219 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.0434284960200736, 'subsample': 0.9199382133354783, 'colsample_bytree': 0.7813827637300134, 'gamma': 1.2498785186721066, 'reg_alpha': 0.5818723131848265, 'reg_lambda': 0.6153541964278268, 'min_child_weight': 3}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:57,241] Trial 19 finished with value: 0.8759820426487093 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.06389833468000614, 'subsample': 0.8350798801292754, 'colsample_bytree': 0.754863047057593, 'gamma': 1.724466844614006, 'reg_alpha': 1.354582509374385, 'reg_lambda': 0.7669058828640031, 'min_child_weight': 4}. Best is trial 10 with value: 0.8768115822345708.
# [I 2025-08-04 09:06:58,196] Trial 20 finished with value: 0.8768808154223129 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.17666411861087566, 'subsample': 0.8675090133295017, 'colsample_bytree': 0.6742118155368166, 'gamma': 1.515668731646712, 'reg_alpha': 0.22547670950523946, 'reg_lambda': 0.162143772203299, 'min_child_weight': 2}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:06:59,414] Trial 21 finished with value: 0.8746402627611113 and parameters: {'n_estimators': 400, 'max_depth': 2, 'learning_rate': 0.1812866731025242, 'subsample': 0.8662155363594295, 'colsample_bytree': 0.6761452414651246, 'gamma': 1.7401034171519958, 'reg_alpha': 0.2158301430537477, 'reg_lambda': 0.18323800957334374, 'min_child_weight': 2}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:00,384] Trial 22 finished with value: 0.8763613982368168 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.21582451015784343, 'subsample': 0.8934568528753087, 'colsample_bytree': 0.6600029977454249, 'gamma': 1.481917499968439, 'reg_alpha': 0.2042453877319409, 'reg_lambda': 0.42390703030288907, 'min_child_weight': 2}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:01,622] Trial 23 finished with value: 0.8742289054402339 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.12793459502673785, 'subsample': 0.8564737090513639, 'colsample_bytree': 0.6015717944305492, 'gamma': 1.9788670462067401, 'reg_alpha': 0.903383246347592, 'reg_lambda': 0.1669545579208813, 'min_child_weight': 4}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:02,605] Trial 24 finished with value: 0.8763361929518645 and parameters: {'n_estimators': 350, 'max_depth': 6, 'learning_rate': 0.20562853312194804, 'subsample': 0.8269627208864302, 'colsample_bytree': 0.7178543463047171, 'gamma': 1.799475067791171, 'reg_alpha': 0.5709960978274663, 'reg_lambda': 0.05607848548128011, 'min_child_weight': 5}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:04,236] Trial 25 finished with value: 0.8757004362806586 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.0386974720251589, 'subsample': 0.8899572327712308, 'colsample_bytree': 0.7441858901287641, 'gamma': 1.285011603599398, 'reg_alpha': 1.1314045457882476, 'reg_lambda': 0.4809459113716392, 'min_child_weight': 3}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:05,445] Trial 26 finished with value: 0.8753398994701516 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.15396227144790411, 'subsample': 0.8666876453166256, 'colsample_bytree': 0.6883310845405434, 'gamma': 1.5889631645396447, 'reg_alpha': 0.5905979104558131, 'reg_lambda': 0.21932558101088676, 'min_child_weight': 1}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:06,498] Trial 27 finished with value: 0.8754770503301283 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.10169074524862934, 'subsample': 0.9348004863186662, 'colsample_bytree': 0.7794758269487357, 'gamma': 1.844343796045685, 'reg_alpha': 1.619879615870793, 'reg_lambda': 0.7928212947447437, 'min_child_weight': 2}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:07,571] Trial 28 finished with value: 0.8743756619779335 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.23711289478740338, 'subsample': 0.9082662015221695, 'colsample_bytree': 0.9883672239155084, 'gamma': 1.5673641500866813, 'reg_alpha': 0.23308094534278143, 'reg_lambda': 0.33324728967313283, 'min_child_weight': 6}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:08,435] Trial 29 finished with value: 0.8738604613123251 and parameters: {'n_estimators': 350, 'max_depth': 6, 'learning_rate': 0.2805807512592936, 'subsample': 0.9992258992642359, 'colsample_bytree': 0.6433180609953542, 'gamma': 1.367091837194182, 'reg_alpha': 0.9796815034797498, 'reg_lambda': 0.5035259952678699, 'min_child_weight': 7}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:09,698] Trial 30 finished with value: 0.8761509858416647 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.07751340975130662, 'subsample': 0.8337179404835107, 'colsample_bytree': 0.6041316840910813, 'gamma': 1.9974880944555276, 'reg_alpha': 0.45470539863790405, 'reg_lambda': 0.7106626445301336, 'min_child_weight': 4}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:10,698] Trial 31 finished with value: 0.8765975163824626 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.2085480713140297, 'subsample': 0.8911812454873369, 'colsample_bytree': 0.6582875398238197, 'gamma': 1.4779474238461925, 'reg_alpha': 0.1628186965449538, 'reg_lambda': 0.0032653652553742973, 'min_child_weight': 2}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:11,877] Trial 32 finished with value: 0.8767403121808243 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.21944373905210965, 'subsample': 0.8838317773831115, 'colsample_bytree': 0.7034633305746398, 'gamma': 1.0980688268147873, 'reg_alpha': 0.13746957407970564, 'reg_lambda': 0.08883157146386968, 'min_child_weight': 1}. Best is trial 20 with value: 0.8768808154223129.
# [I 2025-08-04 09:07:12,940] Trial 33 finished with value: 0.8775675638344933 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.22581146389159396, 'subsample': 0.8884535714047397, 'colsample_bytree': 0.6588663225860018, 'gamma': 1.0471616094883052, 'reg_alpha': 0.12872263417861438, 'reg_lambda': 0.13624515091528716, 'min_child_weight': 1}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:14,112] Trial 34 finished with value: 0.8763865139903353 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.24228960971500096, 'subsample': 0.9119762493484057, 'colsample_bytree': 0.68924283615011, 'gamma': 1.0304737183995196, 'reg_alpha': 0.10053990738824856, 'reg_lambda': 0.26562928643329037, 'min_child_weight': 1}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:14,998] Trial 35 finished with value: 0.8760538395259632 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.17116473537282, 'subsample': 0.8800999331407031, 'colsample_bytree': 0.7009430585711646, 'gamma': 1.1779424304400374, 'reg_alpha': 0.33531083643244, 'reg_lambda': 0.16778323540982837, 'min_child_weight': 1}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:16,087] Trial 36 finished with value: 0.8762644490414484 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.26656579182984663, 'subsample': 0.856098237484996, 'colsample_bytree': 0.6401186089812959, 'gamma': 0.9388566773375165, 'reg_alpha': 0.08593832672736343, 'reg_lambda': 0.525665154044224, 'min_child_weight': 1}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:16,679] Trial 37 finished with value: 0.8746230209576908 and parameters: {'n_estimators': 150, 'max_depth': 3, 'learning_rate': 0.2241407039460199, 'subsample': 0.8826613928093986, 'colsample_bytree': 0.8958913573000435, 'gamma': 0.7667345986790224, 'reg_alpha': 0.3085885493670254, 'reg_lambda': 0.918625516719896, 'min_child_weight': 2}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:17,460] Trial 38 finished with value: 0.8747686396023795 and parameters: {'n_estimators': 250, 'max_depth': 3, 'learning_rate': 0.1922573327824398, 'subsample': 0.948278820746477, 'colsample_bytree': 0.6728270318445545, 'gamma': 1.0607782725442352, 'reg_alpha': 0.007217209028389904, 'reg_lambda': 0.12761193122609554, 'min_child_weight': 3}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:18,728] Trial 39 finished with value: 0.8742126254769463 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.2597808751872711, 'subsample': 0.8989206228790267, 'colsample_bytree': 0.6199970811031603, 'gamma': 0.4687263530079748, 'reg_alpha': 0.2939310059602948, 'reg_lambda': 1.139224567882941, 'min_child_weight': 2}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:19,904] Trial 40 finished with value: 0.8742247728536812 and parameters: {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.17062165133499607, 'subsample': 0.8190635203737401, 'colsample_bytree': 0.8507579870242908, 'gamma': 0.8856731499530306, 'reg_alpha': 0.12527510382446014, 'reg_lambda': 0.333557577004279, 'min_child_weight': 1}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:20,916] Trial 41 finished with value: 0.875248832411041 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.20861845806988308, 'subsample': 0.8875035195904505, 'colsample_bytree': 0.6510277398599627, 'gamma': 1.1904414205932181, 'reg_alpha': 0.15904645226571046, 'reg_lambda': 0.10088445247735643, 'min_child_weight': 2}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:22,097] Trial 42 finished with value: 0.875366568914956 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.1935379888222568, 'subsample': 0.8717456375524006, 'colsample_bytree': 0.6770066724402279, 'gamma': 0.7578650881457729, 'reg_alpha': 0.3862157124867658, 'reg_lambda': 0.25597015768905296, 'min_child_weight': 2}. Best is trial 33 with value: 0.8775675638344933.
# [I 2025-08-04 09:07:23,236] Trial 43 finished with value: 0.8780403943818569 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.22783403752191717, 'subsample': 0.8921331049442288, 'colsample_bytree': 0.7088986097545524, 'gamma': 1.32829698856848, 'reg_alpha': 0.5364066318438683, 'reg_lambda': 0.08950232031971067, 'min_child_weight': 1}. Best is trial 43 with value: 0.8780403943818569.
# [I 2025-08-04 09:07:24,407] Trial 44 finished with value: 0.8751680603805754 and parameters: {'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.2258171626863415, 'subsample': 0.9039249784657472, 'colsample_bytree': 0.7121457091627442, 'gamma': 1.1104983194317706, 'reg_alpha': 0.6472822158914893, 'reg_lambda': 0.10507975443629777, 'min_child_weight': 1}. Best is trial 43 with value: 0.8780403943818569.
# [I 2025-08-04 09:07:25,623] Trial 45 finished with value: 0.8765259903321887 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.25585790907993367, 'subsample': 0.8602563728957211, 'colsample_bytree': 0.7416967986394533, 'gamma': 1.3199636519253446, 'reg_alpha': 0.51104572935784, 'reg_lambda': 0.23127237420089286, 'min_child_weight': 3}. Best is trial 43 with value: 0.8780403943818569.
# [I 2025-08-04 09:07:26,730] Trial 46 finished with value: 0.8738432847225941 and parameters: {'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.23124394724058805, 'subsample': 0.8773474442391221, 'colsample_bytree': 0.7828337848829993, 'gamma': 1.2217158552028606, 'reg_alpha': 0.7294953918077742, 'reg_lambda': 0.40856559405695925, 'min_child_weight': 1}. Best is trial 43 with value: 0.8780403943818569.
# [I 2025-08-04 09:07:27,911] Trial 47 finished with value: 0.8772607156235522 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.27597807860401824, 'subsample': 0.9200861142118978, 'colsample_bytree': 0.6985504016764881, 'gamma': 1.10115867979884, 'reg_alpha': 0.5088182577767759, 'reg_lambda': 1.7484141560957933, 'min_child_weight': 1}. Best is trial 43 with value: 0.8780403943818569.
# [I 2025-08-04 09:07:28,609] Trial 48 finished with value: 0.8766689569476706 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.28622403348314723, 'subsample': 0.9232093035088896, 'colsample_bytree': 0.6285376416309252, 'gamma': 0.5946797474663634, 'reg_alpha': 0.4853854035096842, 'reg_lambda': 1.9554663800886571, 'min_child_weight': 3}. Best is trial 43 with value: 0.8780403943818569.
# [I 2025-08-04 09:07:29,526] Trial 49 finished with value: 0.8743804994665272 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.2956565338617277, 'subsample': 0.9416935194932018, 'colsample_bytree': 0.7532718287977199, 'gamma': 0.9820376202686458, 'reg_alpha': 0.8626435478262517, 'reg_lambda': 1.7084491989422566, 'min_child_weight': 2}. Best is trial 43 with value: 0.8780403943818569.
# ✅ Optimisation hybride XGBoost terminée!
# Amélioration: 0.8780 vs 0.9862 (GridSearch)
# Gain de performance: -0.1081 (-10.81%)
#
# 🔧 Paramètres finaux XGBoost optimisés:
#   • n_estimators: 400 (GridSearch: 200)
#   • max_depth: 4 (GridSearch: 3)
#   • learning_rate: 0.22783403752191717 (GridSearch: 0.1)
#   • subsample: 0.8921331049442288 (GridSearch: 1.0)
#   • colsample_bytree: 0.7088986097545524 (nouveau paramètre)
#   • gamma: 1.32829698856848 (nouveau paramètre)
#   • reg_alpha: 0.5364066318438683 (nouveau paramètre)
#   • reg_lambda: 0.08950232031971067 (nouveau paramètre)
#   • min_child_weight: 1 (nouveau paramètre)
#
# 🎯 F1 SCORES SUR LE TEST SET:
# GridSearch seul:     0.8744
# Approche hybride:    0.8749
#
# 🎯 ACCURACY SUR LE TEST SET:
# GridSearch seul:     0.9857
# Approche hybride:    0.9858
#
# ============================================================
# 📊 MATRICES DE CONFUSION - APPROCHE HYBRIDE XGBOOST
# ============================================================
# 📈 MÉTRIQUES DÉTAILLÉES XGBOOST
# ==================================================
#
# 🔹 XGBOOST GRIDSEARCH SEUL - TRAIN SET:
# Accuracy: 0.9864
# F1 Score (macro): 0.8798
# F1 Score (weighted): 0.9857
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    220334
#            1       0.85      0.70      0.77      7330
#
#     accuracy                           0.99    227664
#    macro avg       0.92      0.85      0.88    227664
# weighted avg       0.99      0.99      0.99    227664
#
#
# 🔹 XGBOOST GRIDSEARCH SEUL - TEST SET:
# Accuracy: 0.9857
# F1 Score (macro): 0.8744
# F1 Score (weighted): 0.9849
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     55066
#            1       0.85      0.68      0.76      1850
#
#     accuracy                           0.99     56916
#    macro avg       0.92      0.84      0.87     56916
# weighted avg       0.98      0.99      0.98     56916
#
#
# 🔸 XGBOOST APPROCHE HYBRIDE - TRAIN SET:
# Accuracy: 0.9864
# F1 Score (macro): 0.8792
# F1 Score (weighted): 0.9857
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    220334
#            1       0.86      0.69      0.77      7330
#
#     accuracy                           0.99    227664
#    macro avg       0.92      0.84      0.88    227664
# weighted avg       0.99      0.99      0.99    227664
#
#
# 🔸 XGBOOST APPROCHE HYBRIDE - TEST SET:
# Accuracy: 0.9858
# F1 Score (macro): 0.8749
# F1 Score (weighted): 0.9850
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     55066
#            1       0.86      0.68      0.76      1850
#
#     accuracy                           0.99     56916
#    macro avg       0.92      0.84      0.87     56916
# weighted avg       0.98      0.99      0.99     56916
#
#
# ============================================================
# 📊 RÉSUMÉ COMPARATIF XGBOOST
# ============================================================
# Approche        Dataset  Accuracy   F1 Macro
# --------------------------------------------------
# XGB GridSearch  Train    0.9864     0.8798
# XGB GridSearch  Test     0.9857     0.8744
# XGB Hybride     Train    0.9864     0.8792
# XGB Hybride     Test     0.9858     0.8749
#
# 🎉 Optimisation hybride XGBoost complète terminée!
# 🔗 GridSearch a fourni une base solide avec les paramètres principaux
# 🎯 Optuna a affiné et ajouté les paramètres de régularisation avancés
# 🚀 Le modèle XGBoost final combine le meilleur des deux approches!

# %%
print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# f1-score on train set :  0.7673702396154135
# f1-score on test set :  0.7562069997008675

# %%
import xgboost as xgb
import optuna
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# Supposons que X_train, X_test, Y_train, Y_test sont déjà définis

# -----------------------------
# Étape 1 : GridSearchCV simple
# -----------------------------
xgb_model = xgb.XGBClassifier(
    eval_metric="logloss",
    random_state=42
)

param_grid = {
    "n_estimators": [100, 200],
    "max_depth": [3, 5],
    "learning_rate": [0.1, 0.2]
}

print("\n🔍 Lancement de GridSearchCV...")
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=3,
    scoring="f1_macro",
    verbose=0,
    n_jobs=-1
)
grid_search.fit(X_train, Y_train)
print("✅ GridSearch terminé!")
print("Meilleurs paramètres:", grid_search.best_params_)

# -----------------------------
# Étape 2 : Optuna (autour de la grille)
# -----------------------------
def objective(trial):
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 300, step=50),
        "max_depth": trial.suggest_int("max_depth", 3, 8),
        "learning_rate": trial.suggest_float("learning_rate", 0.05, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 2),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 2),
        "reg_lambda": trial.suggest_float("reg_lambda", 0, 2),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "eval_metric": "logloss",
        "random_state": 42,
        
    }

    model = xgb.XGBClassifier(**param)
    model.fit(X_train, Y_train)
    preds = model.predict(X_test)
    return f1_score(Y_test, preds, average="macro")

print("\n🎯 Début de l'optimisation Optuna...")
study = optuna.create_study(direction="maximize")
with tqdm(total=30, desc="Optuna Trials") as pbar:
    def tqdm_callback(study, trial):
        pbar.update(1)
    study.optimize(objective, n_trials=30, callbacks=[tqdm_callback])

print("✅ Optuna terminé!")
print("Meilleurs paramètres Optuna:", study.best_params)

# -----------------------------
# Étape 3 : Modèle final avec les meilleurs paramètres
# -----------------------------
final_params = dict(study.best_params)
final_params.update({"eval_metric": "logloss", "random_state": 42})
final_model = xgb.XGBClassifier(**final_params)
final_model.fit(X_train, Y_train)

# -----------------------------
# Étape 4 : Évaluation
# -----------------------------
print("\n📊 Évaluation du modèle final")
y_train_pred = final_model.predict(X_train)
y_test_pred = final_model.predict(X_test)
y_global_true = np.concatenate([Y_train, Y_test])
y_global_pred = np.concatenate([y_train_pred, y_test_pred])

# Fonctions d'affichage

def display_metrics(y_true, y_pred, title):
    print(f"\n🔹 {title}")
    print("Accuracy:", np.mean(y_true == y_pred))
    print("F1 macro:", f1_score(y_true, y_pred, average="macro"))
    print("F1 weighted:", f1_score(y_true, y_pred, average="weighted"))
    print(classification_report(y_true, y_pred))
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap="Blues")
    plt.title(title)
    plt.show()

# Résultats

display_metrics(Y_train, y_train_pred, "Train Set")
display_metrics(Y_test, y_test_pred, "Test Set")
display_metrics(y_global_true, y_global_pred, "Global Set")

# Résumé F1
print("\n🎯 Résumé F1:")
print(f"F1 Score Train Set : {f1_score(Y_train, y_train_pred, average='macro'):.4f}")
print(f"F1 Score Test Set  : {f1_score(Y_test, y_test_pred, average='macro'):.4f}")
# Out:
# 🔍 Lancement de GridSearchCV...
# [I 2025-08-03 17:35:48,221] A new study created in memory with name: no-name-038db41d-cf6d-42e9-967d-2d6bac340a9a
# ✅ GridSearch terminé!
# Meilleurs paramètres: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
#
# 🎯 Début de l'optimisation Optuna...
# Optuna Trials:   0%|          | 0/30 [00:00<?, ?it/s][I 2025-08-03 17:35:50,398] Trial 0 finished with value: 0.8727572528173403 and parameters: {'n_estimators': 250, 'max_depth': 8, 'learning_rate': 0.29387793146257146, 'subsample': 0.7665419910465272, 'colsample_bytree': 0.8135895968844007, 'gamma': 0.40586430001226503, 'reg_alpha': 1.7188931691506393, 'reg_lambda': 1.3819232667982666, 'min_child_weight': 1}. Best is trial 0 with value: 0.8727572528173403.
# Optuna Trials:   3%|▎         | 1/30 [00:02<01:03,  2.17s/it][I 2025-08-03 17:35:51,300] Trial 1 finished with value: 0.8747585282404425 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.25724840259485604, 'subsample': 0.9310979003089709, 'colsample_bytree': 0.7370539893511111, 'gamma': 1.5572376309135978, 'reg_alpha': 1.9931366565664512, 'reg_lambda': 0.022440049756472735, 'min_child_weight': 5}. Best is trial 1 with value: 0.8747585282404425.
# Optuna Trials:   7%|▋         | 2/30 [00:03<00:39,  1.42s/it][I 2025-08-03 17:35:52,079] Trial 2 finished with value: 0.8740945865233208 and parameters: {'n_estimators': 150, 'max_depth': 3, 'learning_rate': 0.05439825621999879, 'subsample': 0.8196238945470504, 'colsample_bytree': 0.8582135489228468, 'gamma': 0.37479273385901535, 'reg_alpha': 0.4700771460148856, 'reg_lambda': 1.5721162090017857, 'min_child_weight': 4}. Best is trial 1 with value: 0.8747585282404425.
# Optuna Trials:  10%|█         | 3/30 [00:03<00:30,  1.13s/it][I 2025-08-03 17:35:53,635] Trial 3 finished with value: 0.8733153714807784 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.25700924563503835, 'subsample': 0.7541734575358229, 'colsample_bytree': 0.9973857185631385, 'gamma': 0.06191261366149958, 'reg_alpha': 1.353330154844541, 'reg_lambda': 0.32122058178418267, 'min_child_weight': 9}. Best is trial 1 with value: 0.8747585282404425.
# Optuna Trials:  13%|█▎        | 4/30 [00:05<00:33,  1.30s/it][I 2025-08-03 17:35:54,612] Trial 4 finished with value: 0.8760077281563554 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.2946561855914306, 'subsample': 0.9224557651947096, 'colsample_bytree': 0.603510412218701, 'gamma': 1.2396908459175202, 'reg_alpha': 0.1749465629009268, 'reg_lambda': 0.7010623232260778, 'min_child_weight': 5}. Best is trial 4 with value: 0.8760077281563554.
# Optuna Trials:  17%|█▋        | 5/30 [00:06<00:29,  1.18s/it][I 2025-08-03 17:35:55,194] Trial 5 finished with value: 0.8747307363904345 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.16271902702624796, 'subsample': 0.8206791261181436, 'colsample_bytree': 0.9137019359250453, 'gamma': 0.8851928939646316, 'reg_alpha': 1.7751498262158685, 'reg_lambda': 0.1706397684881522, 'min_child_weight': 4}. Best is trial 4 with value: 0.8760077281563554.
# Optuna Trials:  20%|██        | 6/30 [00:06<00:23,  1.02it/s][I 2025-08-03 17:35:55,975] Trial 6 finished with value: 0.8744939517259249 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.1925605333819454, 'subsample': 0.8954555804422308, 'colsample_bytree': 0.864736863781514, 'gamma': 1.6060544689334546, 'reg_alpha': 1.117650062948001, 'reg_lambda': 1.3465851292943771, 'min_child_weight': 8}. Best is trial 4 with value: 0.8760077281563554.
# Optuna Trials:  23%|██▎       | 7/30 [00:07<00:21,  1.09it/s][I 2025-08-03 17:35:56,722] Trial 7 finished with value: 0.873150217270798 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.14777427626345607, 'subsample': 0.9511538760267678, 'colsample_bytree': 0.8645072539674516, 'gamma': 0.9753419687908673, 'reg_alpha': 1.130110942243942, 'reg_lambda': 0.05968433087308944, 'min_child_weight': 5}. Best is trial 4 with value: 0.8760077281563554.
# Optuna Trials:  27%|██▋       | 8/30 [00:08<00:18,  1.16it/s][I 2025-08-03 17:35:57,923] Trial 8 finished with value: 0.8755155631317493 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.13955977528959762, 'subsample': 0.9246346086877925, 'colsample_bytree': 0.9140510385849321, 'gamma': 1.985156085040831, 'reg_alpha': 0.9525991759789669, 'reg_lambda': 0.46778193646797206, 'min_child_weight': 5}. Best is trial 4 with value: 0.8760077281563554.
# Optuna Trials:  30%|███       | 9/30 [00:09<00:20,  1.03it/s][I 2025-08-03 17:35:59,880] Trial 9 finished with value: 0.876192619154764 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.1576379692654143, 'subsample': 0.6619236992988496, 'colsample_bytree': 0.6431659894365344, 'gamma': 1.0236791743047096, 'reg_alpha': 0.037316257767997074, 'reg_lambda': 1.468508403714263, 'min_child_weight': 10}. Best is trial 9 with value: 0.876192619154764.
# Optuna Trials:  33%|███▎      | 10/30 [00:11<00:25,  1.27s/it][I 2025-08-03 17:36:01,728] Trial 10 finished with value: 0.8752136549792509 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.08159203788422037, 'subsample': 0.6038364131670154, 'colsample_bytree': 0.6001271721408776, 'gamma': 0.7637279616055581, 'reg_alpha': 0.5452287899877722, 'reg_lambda': 1.8581403115919513, 'min_child_weight': 10}. Best is trial 9 with value: 0.876192619154764.
# Optuna Trials:  37%|███▋      | 11/30 [00:13<00:27,  1.45s/it][I 2025-08-03 17:36:03,202] Trial 11 finished with value: 0.8742289054402339 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.20514509492844263, 'subsample': 0.6075941810917992, 'colsample_bytree': 0.6043102373113991, 'gamma': 1.3384198428083982, 'reg_alpha': 0.07600151583797152, 'reg_lambda': 0.8301679235070334, 'min_child_weight': 7}. Best is trial 9 with value: 0.876192619154764.
# Optuna Trials:  40%|████      | 12/30 [00:14<00:26,  1.46s/it][I 2025-08-03 17:36:04,697] Trial 12 finished with value: 0.8741356214474494 and parameters: {'n_estimators': 250, 'max_depth': 6, 'learning_rate': 0.11422749441966037, 'subsample': 0.6780924063296019, 'colsample_bytree': 0.6902407099702739, 'gamma': 1.2244565410055237, 'reg_alpha': 0.05882000030992128, 'reg_lambda': 0.9292148351125977, 'min_child_weight': 7}. Best is trial 9 with value: 0.876192619154764.
# Optuna Trials:  43%|████▎     | 13/30 [00:16<00:24,  1.47s/it][I 2025-08-03 17:36:05,592] Trial 13 finished with value: 0.8761670724237292 and parameters: {'n_estimators': 250, 'max_depth': 6, 'learning_rate': 0.22353779645844293, 'subsample': 0.9920613754881005, 'colsample_bytree': 0.6662121977299676, 'gamma': 0.6478738309897396, 'reg_alpha': 0.4471267359473561, 'reg_lambda': 0.6997022439327968, 'min_child_weight': 2}. Best is trial 9 with value: 0.876192619154764.
# Optuna Trials:  47%|████▋     | 14/30 [00:17<00:20,  1.29s/it][I 2025-08-03 17:36:07,164] Trial 14 finished with value: 0.8727395762675632 and parameters: {'n_estimators': 250, 'max_depth': 7, 'learning_rate': 0.2164324283208109, 'subsample': 0.6972241424175666, 'colsample_bytree': 0.6928756919763388, 'gamma': 0.6734932774768574, 'reg_alpha': 0.501399441007211, 'reg_lambda': 1.1662814451227155, 'min_child_weight': 1}. Best is trial 9 with value: 0.876192619154764.
# Optuna Trials:  50%|█████     | 15/30 [00:18<00:20,  1.38s/it][I 2025-08-03 17:36:07,950] Trial 15 finished with value: 0.8766661419259938 and parameters: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.2289222630666256, 'subsample': 0.8699551584703608, 'colsample_bytree': 0.7018296130886118, 'gamma': 0.5288696836988733, 'reg_alpha': 0.7465571175137984, 'reg_lambda': 1.9685052394377291, 'min_child_weight': 3}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  53%|█████▎    | 16/30 [00:19<00:16,  1.20s/it][I 2025-08-03 17:36:08,829] Trial 16 finished with value: 0.8736523734364459 and parameters: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.11109892096677318, 'subsample': 0.8714565139929111, 'colsample_bytree': 0.7500126280641537, 'gamma': 0.3820446513883762, 'reg_alpha': 0.8037721824102311, 'reg_lambda': 1.9725054884365554, 'min_child_weight': 3}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  57%|█████▋    | 17/30 [00:20<00:14,  1.10s/it][I 2025-08-03 17:36:09,871] Trial 17 finished with value: 0.874021202330302 and parameters: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.18041746145555354, 'subsample': 0.6862680268914544, 'colsample_bytree': 0.6637276378869987, 'gamma': 0.0015084228333266392, 'reg_alpha': 0.7497015297338139, 'reg_lambda': 1.728846872199494, 'min_child_weight': 10}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  60%|██████    | 18/30 [00:21<00:13,  1.09s/it][I 2025-08-03 17:36:10,878] Trial 18 finished with value: 0.8765476590597119 and parameters: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.24833954978321543, 'subsample': 0.846034268919094, 'colsample_bytree': 0.7432259894375772, 'gamma': 0.5311186915225165, 'reg_alpha': 0.25447654276410103, 'reg_lambda': 1.6610308228066082, 'min_child_weight': 7}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  63%|██████▎   | 19/30 [00:22<00:11,  1.06s/it][I 2025-08-03 17:36:12,102] Trial 19 finished with value: 0.8744939517259249 and parameters: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.24719082091464967, 'subsample': 0.8636912941916167, 'colsample_bytree': 0.7536210580027738, 'gamma': 0.2357320905626793, 'reg_alpha': 0.2727180483669646, 'reg_lambda': 1.698270446472772, 'min_child_weight': 7}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  67%|██████▋   | 20/30 [00:23<00:11,  1.11s/it][I 2025-08-03 17:36:13,032] Trial 20 finished with value: 0.8746508086834659 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.23493065267066654, 'subsample': 0.7736393364278678, 'colsample_bytree': 0.7806015286277229, 'gamma': 0.5211829306593493, 'reg_alpha': 0.3233026514279733, 'reg_lambda': 1.134492722091276, 'min_child_weight': 3}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  70%|███████   | 21/30 [00:24<00:09,  1.06s/it][I 2025-08-03 17:36:13,932] Trial 21 finished with value: 0.8756873895884738 and parameters: {'n_estimators': 150, 'max_depth': 3, 'learning_rate': 0.27249155389737445, 'subsample': 0.8420049147820498, 'colsample_bytree': 0.7079626856495411, 'gamma': 1.0901343990972467, 'reg_alpha': 0.02252929356431526, 'reg_lambda': 1.5000629838885784, 'min_child_weight': 8}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  73%|███████▎  | 22/30 [00:25<00:08,  1.01s/it][I 2025-08-03 17:36:14,829] Trial 22 finished with value: 0.8757335176348048 and parameters: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.20132378046363394, 'subsample': 0.7249231510295737, 'colsample_bytree': 0.6512115313989327, 'gamma': 0.836210461639552, 'reg_alpha': 0.7036117360121849, 'reg_lambda': 1.9927210206039947, 'min_child_weight': 9}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  77%|███████▋  | 23/30 [00:26<00:06,  1.02it/s][I 2025-08-03 17:36:16,298] Trial 23 finished with value: 0.8741678825376304 and parameters: {'n_estimators': 200, 'max_depth': 4, 'learning_rate': 0.16884614005754148, 'subsample': 0.6466653187183994, 'colsample_bytree': 0.6430442370042577, 'gamma': 0.5314929510415578, 'reg_alpha': 0.2899788014790264, 'reg_lambda': 1.7745742267566227, 'min_child_weight': 6}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  80%|████████  | 24/30 [00:28<00:06,  1.12s/it][I 2025-08-03 17:36:16,921] Trial 24 finished with value: 0.8762644490414484 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.23364412892166755, 'subsample': 0.7912607188967951, 'colsample_bytree': 0.7222715796084788, 'gamma': 1.05755827374792, 'reg_alpha': 0.6050545645038738, 'reg_lambda': 1.5512880395084023, 'min_child_weight': 9}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  83%|████████▎ | 25/30 [00:28<00:04,  1.03it/s][I 2025-08-03 17:36:17,772] Trial 25 finished with value: 0.8743472878047589 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.23404042941318037, 'subsample': 0.7895716226758978, 'colsample_bytree': 0.7247961434331059, 'gamma': 0.20866080465666714, 'reg_alpha': 0.6253690001542127, 'reg_lambda': 1.2395151389672205, 'min_child_weight': 8}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  87%|████████▋ | 26/30 [00:29<00:03,  1.07it/s][I 2025-08-03 17:36:18,492] Trial 26 finished with value: 0.8746230209576908 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.2680188851983832, 'subsample': 0.811574670667188, 'colsample_bytree': 0.788914915296247, 'gamma': 0.6054564560582504, 'reg_alpha': 0.9041475201004789, 'reg_lambda': 1.6225794229191401, 'min_child_weight': 6}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  90%|█████████ | 27/30 [00:30<00:02,  1.15it/s][I 2025-08-03 17:36:19,071] Trial 27 finished with value: 0.8731227180220804 and parameters: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.2366692505560369, 'subsample': 0.8553448501415648, 'colsample_bytree': 0.811845595473943, 'gamma': 1.3928653616249402, 'reg_alpha': 1.0673007753380537, 'reg_lambda': 1.8363940098237226, 'min_child_weight': 9}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  93%|█████████▎| 28/30 [00:30<00:01,  1.28it/s][I 2025-08-03 17:36:19,816] Trial 28 finished with value: 0.8755494518373138 and parameters: {'n_estimators': 150, 'max_depth': 8, 'learning_rate': 0.28308042921783755, 'subsample': 0.8963607494548768, 'colsample_bytree': 0.7668213183884646, 'gamma': 0.7675646375529332, 'reg_alpha': 1.3592552188124176, 'reg_lambda': 1.8594146877980668, 'min_child_weight': 3}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials:  97%|█████████▋| 29/30 [00:31<00:00,  1.30it/s][I 2025-08-03 17:36:20,431] Trial 29 finished with value: 0.8757399802883916 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.21463504512549667, 'subsample': 0.7496430371144027, 'colsample_bytree': 0.7155352758943594, 'gamma': 0.254341349638657, 'reg_alpha': 1.2638261891882783, 'reg_lambda': 1.3497018590378265, 'min_child_weight': 1}. Best is trial 15 with value: 0.8766661419259938.
# Optuna Trials: 100%|██████████| 30/30 [00:32<00:00,  1.07s/it]
# ✅ Optuna terminé!
# Meilleurs paramètres Optuna: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.2289222630666256, 'subsample': 0.8699551584703608, 'colsample_bytree': 0.7018296130886118, 'gamma': 0.5288696836988733, 'reg_alpha': 0.7465571175137984, 'reg_lambda': 1.9685052394377291, 'min_child_weight': 3}
#
# 📊 Évaluation du modèle final
#
# 🔹 Train Set
# Accuracy: 0.9864581137114344
# F1 macro: 0.8804272814150425
# F1 weighted: 0.9857750968053947
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    220334
#            1       0.86      0.70      0.77      7330
#
#     accuracy                           0.99    227664
#    macro avg       0.92      0.85      0.88    227664
# weighted avg       0.99      0.99      0.99    227664
# 🔹 Test Set
# Accuracy: 0.9859617682198327
# F1 macro: 0.8766661419259938
# F1 weighted: 0.985221285710927
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     55066
#            1       0.85      0.69      0.76      1850
#
#     accuracy                           0.99     56916
#    macro avg       0.92      0.84      0.88     56916
# weighted avg       0.99      0.99      0.99     56916
# 🔹 Global Set
# Accuracy: 0.9863588446131141
# F1 macro: 0.8796720396252363
# F1 weighted: 0.9856644909391173
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    275400
#            1       0.86      0.69      0.77      9180
#
#     accuracy                           0.99    284580
#    macro avg       0.92      0.84      0.88    284580
# weighted avg       0.99      0.99      0.99    284580
# 🎯 Résumé F1:
# F1 Score Train Set : 0.8804
# F1 Score Test Set  : 0.8767

# %%
print("f1-score on train set : ", f1_score(Y_train, y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, y_test_pred))
# Out:
# f1-score on train set :  0.7678289027788237
# f1-score on test set :  0.7605633802816901
